# %%
import pandas as pd
profile = ['2025-06-28','안채연','2001-01-10','ESTJ']
profile = pd.Series(profile)

# %%
profile
# Out:
# 0    2025-06-28
# 1           안채연
# 2    2001-01-10
# 3          ESTJ
# dtype: object
